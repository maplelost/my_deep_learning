# %% [markdown]
# ## 梯度下降
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 小批量随机梯度下降
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
