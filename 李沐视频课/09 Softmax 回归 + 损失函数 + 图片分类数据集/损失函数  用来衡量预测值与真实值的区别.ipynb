# %% [markdown]
# # 损失函数
# ## 均方损失
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ## 箭头代表更新的权重的大小

# %% [markdown]
# ## 绝对值损失函数
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Hubert's Robust Loss
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
