# %% [markdown]
# # 从回归到多类分类
# ![image.png](attachment:image.png)

# %% [markdown]
# # 从回归到多类分类-均方损失
# ![image.png](attachment:image.png)

# %% [markdown]
# # 无校验比例
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Softmax和交叉熵损失
# ![image.png](attachment:image.png)

# %% [markdown]
# # Softmax回归
# ![image.png](attachment:image.png)
