# %% [markdown]
# # 为了使数值稳定，有三种方法
# ![image.png](attachment:17c0e48a-0749-493b-9059-811498671d80.png)

# %% [markdown]
# ## 方法一:使用合理的初始化权重以及激活函数
# ![image.png](attachment:f2a70691-7407-4460-91c7-33a9e5d5ddba.png)

# %% [markdown]
# ## 权重初始化
# ![image.png](attachment:ed60ddac-4ba0-4259-b896-cada4f60fd42.png)

# %% [markdown]
# ## 例子
# ![image.png](attachment:ae5d480f-dcc4-4af4-a095-96fe15704a1d.png)

# %% [markdown]
# ## 正向方差
# ![image.png](attachment:727c75e9-d701-4019-85fb-714cbec9f7bf.png)

# %% [markdown]
# ## 反向均值和方差
# ![image.png](attachment:46cedc9d-5dd9-4279-905e-a969c5bd2558.png)

# %% [markdown]
# ## Xavier初始化
# ![image.png](attachment:1c37b66a-a7ff-4378-bcd3-92decb8e3939.png)

# %% [markdown]
# # 激活函数的选取
# ## 假设线性的激活函数
# 可以得出，当a=1,b=0时，即输入=输出的线性激活函数最好
# 于是我们选择输入最接近输出的常用的激活函数来逼近这一效果
# ![image.png](attachment:2f8bde96-14c1-41a4-8bc6-b39a3ca5ee34.png)
# ![image.png](attachment:52779d13-0b74-4fae-b62e-d7054a00818e.png)
