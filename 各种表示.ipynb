# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 向量点积
# ![image.png](attachment:image.png)

# %% [markdown]
# # 矩阵向量积
# ![image.png](attachment:image.png)
# 很重要的一点，矩阵的列维数，必须要与向量的维数相同。

# %%
import torch
A = torch.tensor([[1,2,3],[1,2,3]])

# %%
x = torch.tensor([[1,2,3],[1,2,3],[1,2,3]]) 
torch.mm(A,x)
# Out:
# tensor([[ 6, 12, 18],
#         [ 6, 12, 18]])
